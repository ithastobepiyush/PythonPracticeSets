# %%
string = "Python Coding in Python is enjoyable, isn't it?"
string2 = "Python is fun and learning Python is even more fun when you practice Python every day because practice makes learning fun Python is fun and learning Python is even more fun when you practice Python every day because practice makes learning fun"
print(f"string: \t{string}\nstring2:\t{string2}")
# Out:
# string: 	Python Coding in Python is enjoyable, isn't it?
# string2:	Python is fun and learning Python is even more fun when you practice Python every day because practice makes learning fun Python is fun and learning Python is even more fun when you practice Python every day because practice makes learning fun

# %%
givenstring="Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet. Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet."
print(f"givenstring:\t{givenstring}")
# Out:
# givenstring:	Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet. Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet.

# %%
import matplotlib.pyplot as plt

class TextAnalyzer:
    def __init__(self, text):
        # for removing punctuations and all of that stuff
        formattedText = text.replace('?','').replace('!','').replace(',','').replace('.','').replace('\'','')
        # to convert the whole sentence or para in lowercase to standerise all of the cases to lower
        formattedText = formattedText.lower()
        self.frmtText = formattedText
   
    # creating a dictionary for the kjkey value pairs
    
    def freqAll(self):
        # splitting the words from whole string and then storing them in a list
        # Step 1: Split into words and then stores in wordList
        wordList = self.frmtText.split()
        # Step 2: Create empty dictionary
        freqMap = {}
        # Step 3 & 4: Loop and count occurrences
        for word in set(wordList):
            freqMap[word] = wordList.count(word)
        # Step 5: Return the frequency dictionary
        return freqMap


    # freqOf(word) → relies on freqAll() → gets full frequency dictionary → returns only the count for `word`
    def freqOf(self, word):
        freqDict = self.freqAll()
        if word in freqDict:
            return freqDict[word]
        else:
            return 0
            
    def showGraph(self):
        freqMap = self.freqAll()
        
        # Plotting bar graph
        plt.figure(figsize=(14, 4))
        plt.bar(freqMap.keys(), freqMap.values(), color='yellow')
        plt.title("Word Frequency Visualization")
        plt.xlabel("Words")
        plt.ylabel("Count")
        plt.xticks(rotation=0)
        plt.show()

# %%
TestSub = TextAnalyzer(givenstring)

# TestSub.freqAll() is a method of class TextAnalyzer:
# print(TestSub.freqAll())
# word = 'lorem'
# freq = TestSub.freqOf(word)
# print(f"word: {word} and it's frequency freq: {freq}")

# method of class TextAnalyzer(object): 
TestSub.showGraph()

# %%
TextSubject1 = TextAnalyzer(string)
print(f"Formatted Text:\n{TextSubject1.frmtText} ")
print(f"Frequency of text in TextSubj1:\n{TextSubject1.freqAll()}")
TextSubject1.showGraph()
TextSubject1.freqOf('python')
# Out:
# Formatted Text:
# python coding in python is enjoyable isnt it
# Frequency of text in TextSubj1:
# {'python': 2, 'is': 1, 'coding': 1, 'isnt': 1, 'in': 1, 'it': 1, 'enjoyable': 1}
# 2

# %%
TextSubject2 = TextAnalyzer(string2)
print(f"Formatted Text:\n\n{TextSubject2.frmtText}\n")
print(f"Frequency of text in TextSubj2:\n{TextSubject2.freqAll()}")
TextSubject2.showGraph()
# Out:
# Formatted Text:
#
# python is fun and learning python is even more fun when you practice python every day because practice makes learning fun python is fun and learning python is even more fun when you practice python every day because practice makes learning fun
#
# Frequency of text in TextSubj2:
# {'when': 2, 'day': 2, 'python': 6, 'is': 4, 'more': 2, 'you': 2, 'and': 2, 'learning': 4, 'makes': 2, 'because': 2, 'every': 2, 'fun': 6, 'practice': 4, 'even': 2}
